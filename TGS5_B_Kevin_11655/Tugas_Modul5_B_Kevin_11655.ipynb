# %% [markdown]
# # Menggunakan Library Tensorflow

# %%
import tensorflow as tf ##jika error,  install tensorflow terlebih dahulu
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import logging
logging.getLogger('matplotlib.font_manager').disabled = True
import random

seed_value = 55
tf.random.set_seed(seed_value) 
np.random.seed(seed_value)      
random.seed(seed_value)

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist  
                                                 
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
plt.figure() 
plt.imshow(train_images[0]) 
plt.colorbar() 
plt.grid(False)
plt.show()

# %%
train_images = train_images.reshape(-1, 28, 28, 1).astype('float32') / 255
test_images = test_images.reshape(-1, 28, 28, 1).astype('float32') / 255

# %%
plt.figure(figsize=(10,10)) 
for i in range(25): 
    plt.subplot(5,5,i+1) 
    plt.xticks([]) 
    plt.yticks([]) 
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary) 
    plt.xlabel(class_names[train_labels[i]]) 
plt.show()

# %%
model_tf = tf.keras.Sequential([ 
    tf.keras.layers.Input(shape=(28, 28)), 
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(300, activation='relu'),  
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(10)
])

# %%
model_tf.compile(optimizer='adam', 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping


early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=5,
    min_delta=0.0001,
    restore_best_weights=True  
)


history = model_tf.fit(
    train_images, train_labels,
    epochs=40,
    validation_data=(test_images, test_labels),
    callbacks=[early_stopping]  
)
# Out:
# Epoch 1/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7300 - loss: 0.7529 - val_accuracy: 0.8405 - val_loss: 0.4368
# Epoch 2/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8339 - loss: 0.4558 - val_accuracy: 0.8533 - val_loss: 0.3981
# Epoch 3/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8514 - loss: 0.4150 - val_accuracy: 0.8487 - val_loss: 0.4006
# Epoch 4/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8558 - loss: 0.3945 - val_accuracy: 0.8604 - val_loss: 0.3818
# Epoch 5/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8619 - loss: 0.3809 - val_accuracy: 0.8580 - val_loss: 0.3847
# Epoch 6/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8632 - loss: 0.3707 - val_accuracy: 0.8652 - val_loss: 0.3622
# Epoch 7/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8699 - loss: 0.3607 - val_accuracy: 0.8694 - val_loss: 0.3661
# Epoch 8/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8709 - loss: 0.3518 - val_accuracy: 0.8667 - val_loss: 0.3639
# Epoch 9/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8752 - loss: 0.3408 - val_accuracy: 0.8682 - val_loss: 0.3652
# Epoch 10/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8770 - loss: 0.3402 - val_accuracy: 0.8737 - val_loss: 0.3499
# Epoch 11/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8799 - loss: 0.3346 - val_accuracy: 0.8745 - val_loss: 0.3418
# Epoch 12/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8825 - loss: 0.3241 - val_accuracy: 0.8755 - val_loss: 0.3438
# Epoch 13/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8827 - loss: 0.3189 - val_accuracy: 0.8698 - val_loss: 0.3599
# Epoch 14/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8850 - loss: 0.3142 - val_accuracy: 0.8704 - val_loss: 0.3504
# Epoch 15/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8838 - loss: 0.3114 - val_accuracy: 0.8731 - val_loss: 0.3495
# Epoch 16/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8865 - loss: 0.3088 - val_accuracy: 0.8658 - val_loss: 0.3566
# Epoch 17/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8851 - loss: 0.3094 - val_accuracy: 0.8769 - val_loss: 0.3380
# Epoch 18/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8882 - loss: 0.3043 - val_accuracy: 0.8728 - val_loss: 0.3492
# Epoch 19/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8880 - loss: 0.3010 - val_accuracy: 0.8767 - val_loss: 0.3385
# Epoch 20/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8893 - loss: 0.2990 - val_accuracy: 0.8762 - val_loss: 0.3561
# Epoch 21/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8916 - loss: 0.2958 - val_accuracy: 0.8730 - val_loss: 0.3551
# Epoch 22/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8902 - loss: 0.2954 - val_accuracy: 0.8783 - val_loss: 0.3435
# Epoch 23/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8944 - loss: 0.2882 - val_accuracy: 0.8719 - val_loss: 0.3501
# Epoch 24/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8954 - loss: 0.2866 - val_accuracy: 0.8824 - val_loss: 0.3382
# Epoch 25/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8937 - loss: 0.2951 - val_accuracy: 0.8848 - val_loss: 0.3271
# Epoch 26/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8957 - loss: 0.2812 - val_accuracy: 0.8790 - val_loss: 0.3460
# Epoch 27/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8957 - loss: 0.2822 - val_accuracy: 0.8815 - val_loss: 0.3358
# Epoch 28/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8965 - loss: 0.2823 - val_accuracy: 0.8761 - val_loss: 0.3481
# Epoch 29/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8974 - loss: 0.2794 - val_accuracy: 0.8805 - val_loss: 0.3479
# Epoch 30/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8977 - loss: 0.2797 - val_accuracy: 0.8776 - val_loss: 0.3467

# %%
fig = plt.figure()
plt.plot(history.history['val_accuracy'], color = 'teal', label = 'Validation Accuracy')  
plt.plot(history.history['accuracy'], color = 'orange', label = 'Train Accuracy')
plt.legend(loc = "upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['val_loss'], color = 'blue', label = 'Validation Loss')
plt.plot(history.history['loss'], color = 'orange', label = 'Train Loss')
plt.legend(loc = "upper left")
plt.show()

# %%
test_loss, test_acc_tf = model_tf.evaluate(test_images, test_labels, verbose=2) 
                                                                                
print('\nTest accuracy:', test_acc_tf)
# Out:
# 313/313 - 0s - 737us/step - accuracy: 0.8848 - loss: 0.3271
#
# Test accuracy: 0.8848000168800354

# %%
probability_model = tf.keras.Sequential([model_tf, 
                                         tf.keras.layers.Softmax()])

# %%
predictions_tf = probability_model.predict(test_images)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step

# %%
predictions_tf[0]
# Out:
# array([1.8475905e-08, 1.6321473e-09, 1.1448381e-09, 4.2165151e-08,
#        2.8081284e-09, 5.5145111e-04, 8.1279747e-09, 1.3585459e-02,
#        2.6666724e-08, 9.8586303e-01], dtype=float32)

# %%
np.argmax(predictions_tf[0])
# Out:
# np.int64(9)

# %%
test_labels[0]
# Out:
# np.uint8(9)

# %%
def plot_image(i, predictions_array, true_label, img):  

    true_label, img = true_label[i], img[i]  
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)


    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label): 
                                                       
    true_label = true_label[i]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
i = 5 
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions_tf[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions_tf[i], test_labels)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

num_rows = 5
num_cols = 4
num_images = num_rows * num_cols

correct_predictions = [np.argmax(predictions_tf[i]) == test_labels[i] for i in range(num_images)]
average_accuracy = np.mean(correct_predictions) * 100  

plt.figure(figsize=(2 * 2 * num_cols, 2 * num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2 * num_cols, 2 * i + 1)
    plot_image(i, predictions_tf[i], test_labels, test_images)
    border_color = 'green' if correct_predictions[i] else 'red'
    plt.gca().patch.set_edgecolor(border_color)
    plt.gca().patch.set_linewidth(3)
    
    plt.subplot(num_rows, 2 * num_cols, 2 * i + 2)
    plot_value_array(i, predictions_tf[i], test_labels)

plt.suptitle(f'Akurasi Rata-rata: {average_accuracy:.2f}%')
plt.tight_layout()
plt.show()

# %%
img = test_images[1] 

print(img.shape)
# Out:
# (28, 28, 1)

# %%
img = (np.expand_dims(img,0))

print(img.shape)
# Out:
# (1, 28, 28, 1)

# %%
predictions_single = probability_model.predict(img) 
print(predictions_single)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[5.0967385e-04 8.7438941e-08 9.7497720e-01 2.4910460e-07 1.4142237e-02
#   3.3615554e-12 1.0370520e-02 6.3430668e-15 3.3433125e-08 2.2739931e-14]]

# %%
plot_value_array(1, predictions_single[0], test_labels) 
_ = plt.xticks(range(10), class_names, rotation=45) 
plt.show()

# %%
np.argmax(predictions_single[0])
# Out:
# np.int64(2)

# %%
df_test = pd.DataFrame({
    'Target': test_labels,  
    'Predicted': np.argmax(predictions_tf, axis=1),  
    'Proba_0': predictions_tf[:, 0],  
    'Proba_1': predictions_tf[:, 1]  
})

pixels = test_images.reshape(len(test_images), -1)

df_pixels = pd.DataFrame(pixels, columns=[f'pixel{i+1}' for i in range(28*28)])

df_test = pd.concat([df_test, df_pixels], axis=1)

# %%
df_plot = df_test.sample(16, random_state=55).copy()
fig, ax = plt.subplots(4, 4, figsize=(10, 10))

rata2_accuracy = (df_test['Target'] == df_test['Predicted']).mean() * 100

for i, axi in enumerate(ax.flat):
    p0 = df_plot['Proba_0'].values[i]
    p1 = df_plot['Proba_1'].values[i]
    
    predicted_class = df_plot['Predicted'].values[i]
    prediction_probability = max(p0, p1) * 100

    true_class = df_plot['Target'].values[i]

    pixels = df_plot[[f'pixel{j}' for j in range(1, 28*28 + 1)]].values[i].reshape(28, 28)
    axi.imshow(pixels, cmap='viridis')

    axi.set(xticks=[], yticks=[], xlabel=f"True: {true_class}\nPred: {predicted_class}\nProb: {prediction_probability:.2f}%")

    edge_color = 'green' if predicted_class == true_class else 'red'
    axi.spines[:].set_edgecolor(edge_color)
    axi.spines[:].set_linewidth(3)

fig.suptitle(f'Contoh gambar yang diklasifikasikan dari set pengujian\n'
             f'Batas hijau: klasifikasi benar\nAkurasi Keseluruhan: {rata2_accuracy:.2f}%')
fig.tight_layout()
plt.show()

# %% [markdown]
# # Menggunakan Library Scikit-Learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import tensorflow as tf

# %%
import warnings
warnings.filterwarnings("ignore");
warnings.simplefilter("ignore");

# %%
from sklearn.datasets import fetch_openml
fashion_mnist = fetch_openml('Fashion-MNIST', version=1)


train_images = fashion_mnist.data[:60000] 
train_labels = fashion_mnist.target[:60000].astype(int)    
test_images = fashion_mnist.data[60000:] 
test_labels = fashion_mnist.target[60000:].astype(int)

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, log_loss
from sklearn.model_selection import train_test_split
import numpy as np

train_images_split, val_images, train_labels_split, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=55)

model_sklearn = MLPClassifier(hidden_layer_sizes=(128,300),
                      activation='relu',
                      alpha=0.0001,
                      learning_rate_init=0.001,
                      early_stopping=True,
                      validation_fraction=0.2,
                      n_iter_no_change=10,
                      random_state=55,
                      verbose=True)

model_sklearn.fit(train_images_split, train_labels_split)
training_loss = model_sklearn.loss_curve_
# Out:
# Iteration 1, loss = 0.62390859
# Validation score: 0.845417
# Iteration 2, loss = 0.41924839
# Validation score: 0.852500
# Iteration 3, loss = 0.36914210
# Validation score: 0.868125
# Iteration 4, loss = 0.34208881
# Validation score: 0.864167
# Iteration 5, loss = 0.32779594
# Validation score: 0.867292
# Iteration 6, loss = 0.30468246
# Validation score: 0.882604
# Iteration 7, loss = 0.28716475
# Validation score: 0.883437
# Iteration 8, loss = 0.28321076
# Validation score: 0.882396
# Iteration 9, loss = 0.26359449
# Validation score: 0.888542
# Iteration 10, loss = 0.25412391
# Validation score: 0.891146
# Iteration 11, loss = 0.24647580
# Validation score: 0.889375
# Iteration 12, loss = 0.23738320
# Validation score: 0.883021
# Iteration 13, loss = 0.23057996
# Validation score: 0.886146
# Iteration 14, loss = 0.22183017
# Validation score: 0.885000
# Iteration 15, loss = 0.21426792
# Validation score: 0.889687
# Iteration 16, loss = 0.20989800
# Validation score: 0.892188
# Iteration 17, loss = 0.20060374
# Validation score: 0.888021
# Iteration 18, loss = 0.19056881
# Validation score: 0.891042
# Iteration 19, loss = 0.18457620
# Validation score: 0.886354
# Iteration 20, loss = 0.17974512
# Validation score: 0.885000
# Iteration 21, loss = 0.17828878
# Validation score: 0.887396
# Iteration 22, loss = 0.17363815
# Validation score: 0.891771
# Iteration 23, loss = 0.16316853
# Validation score: 0.889896
# Iteration 24, loss = 0.16003894
# Validation score: 0.887708
# Iteration 25, loss = 0.15461262
# Validation score: 0.891458
# Iteration 26, loss = 0.14702159
# Validation score: 0.885938
# Iteration 27, loss = 0.14502390
# Validation score: 0.892604
# Iteration 28, loss = 0.13686462
# Validation score: 0.890625
# Iteration 29, loss = 0.13495347
# Validation score: 0.891875
# Iteration 30, loss = 0.13325391
# Validation score: 0.891667
# Iteration 31, loss = 0.12198179
# Validation score: 0.885417
# Iteration 32, loss = 0.12614023
# Validation score: 0.894896
# Iteration 33, loss = 0.11542522
# Validation score: 0.892708
# Iteration 34, loss = 0.11340121
# Validation score: 0.892500
# Iteration 35, loss = 0.10823302
# Validation score: 0.887708
# Iteration 36, loss = 0.10606223
# Validation score: 0.884479
# Iteration 37, loss = 0.10591202
# Validation score: 0.891458
# Iteration 38, loss = 0.09958089
# Validation score: 0.893021
# Iteration 39, loss = 0.09618551
# Validation score: 0.883542
# Iteration 40, loss = 0.09483694
# Validation score: 0.890417
# Iteration 41, loss = 0.08610356
# Validation score: 0.895521
# Iteration 42, loss = 0.08866762
# Validation score: 0.891771
# Iteration 43, loss = 0.08404944
# Validation score: 0.893333
# Iteration 44, loss = 0.08236747
# Validation score: 0.888542
# Iteration 45, loss = 0.07838294
# Validation score: 0.888646
# Iteration 46, loss = 0.07452131
# Validation score: 0.889062
# Iteration 47, loss = 0.07514114
# Validation score: 0.890417
# Iteration 48, loss = 0.07295842
# Validation score: 0.885521
# Iteration 49, loss = 0.06361629
# Validation score: 0.894271
# Iteration 50, loss = 0.05923269
# Validation score: 0.892292
# Iteration 51, loss = 0.06354808
# Validation score: 0.889896
# Iteration 52, loss = 0.06334832
# Validation score: 0.889167
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, val_scores = learning_curve(
    model_sklearn, train_images, train_labels, train_sizes=np.linspace(0.1, 1.0, 10), cv=5,
    scoring='neg_log_loss', random_state=55, n_jobs=-1)

train_loss_mean = -train_scores.mean(axis=1)
val_loss_mean = -val_scores.mean(axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_loss_mean, label='Training Loss')
plt.plot(train_sizes, val_loss_mean, label='Validation Loss')
plt.xlabel('Training Set Size')
plt.ylabel('Loss')
plt.title('Learning Curve (Training vs Validation Loss)')
plt.legend()
plt.show()

# %%
test_predictions = model_sklearn.predict(test_images)
test_acc_sklearn = accuracy_score(test_labels, test_predictions)
print('\nTest Accuracy:', test_acc_sklearn)
# Out:
# Test Accuracy: 0.8853

# %%
print("\nClassification Report:\n", classification_report(test_labels, test_predictions))

predictions_proba = model_sklearn.predict_proba(test_images)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83      1000
#            1       0.99      0.96      0.98      1000
#            2       0.85      0.77      0.81      1000
#            3       0.83      0.93      0.88      1000
#            4       0.82      0.82      0.82      1000
#            5       0.97      0.95      0.96      1000
#            6       0.72      0.69      0.70      1000
#            7       0.93      0.96      0.94      1000
#            8       0.98      0.96      0.97      1000
#            9       0.96      0.95      0.96      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.88     10000
# weighted avg       0.89      0.89      0.88     10000

# %%
predictions_sklearn = model_sklearn.predict_proba(test_images)
print(predictions_sklearn[0])  

print("Predicted label for first image:", np.argmax(predictions_sklearn[0]))

print("Actual label for first image:", test_labels.iloc[0])
# Out:
# [3.35862121e-13 1.29327467e-12 3.87716673e-09 4.63028669e-12
#  7.80063188e-10 3.04921069e-07 1.05751850e-11 1.80984605e-05
#  1.76937820e-12 9.99981592e-01]
# Predicted label for first image: 9
# Actual label for first image: 9

# %%
def plot_image(i, predictions_array, true_label, img):
    true_label, img = true_label.iloc[i], img.iloc[i].values.reshape(28, 28) 
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    color = 'blue' if predicted_label == true_label else 'red'

    plt.xlabel(f"{class_names[predicted_label]} {100*np.max(predictions_array):.2f}% ({class_names[true_label]})", color=color)

def plot_value_array(i, predictions_array, true_label):
    true_label = true_label.iloc[i] 
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
i = 1
plt.figure(figsize=(6, 3))
plt.subplot(1, 2, 1)
plot_image(i, predictions_sklearn[i], test_labels, test_images)
plt.subplot(1, 2, 2)
plot_value_array(i, predictions_sklearn[i], test_labels)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

num_rows = 5
num_cols = 4
num_images = num_rows * num_cols

correct_predictions = [np.argmax(predictions_sklearn[i]) == test_labels.iloc[i] for i in range(num_images)]
average_accuracy = np.mean(correct_predictions) *100

plt.figure(figsize=(2 * 2 * num_cols, 2 * num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2 * num_cols, 2 * i + 1)
    plot_image(i, predictions_sklearn[i], test_labels, test_images)
    border_color = 'green' if correct_predictions[i] else 'red'
    plt.gca().patch.set_edgecolor(border_color)
    plt.gca().patch.set_linewidth(3)

    plt.subplot(num_rows, 2 * num_cols, 2 * i + 2)
    plot_value_array(i, predictions_sklearn[i], test_labels)

plt.suptitle(f'Akurasi Rata-rata: {average_accuracy:.2f}%')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

n_samples = 10000

df_test = pd.DataFrame({
    'Target': test_labels,  
    'Predicted': np.argmax(predictions_sklearn, axis=1),
    'Proba_0': predictions_sklearn[:,0],
    'Proba_1': predictions_sklearn[:,1],
})

df_test['Proba_0'] = df_test['Proba_0'] / (df_test['Proba_0'] + df_test['Proba_1'])
df_test['Proba_1'] = 1 - df_test['Proba_0']

for i in range(1, 28*28 + 1):
    df_test[f'pixel{i}'] = np.random.randint(0, 256, n_samples)

df_plot = df_test.sample(16, random_state=55).copy()

fig, ax = plt.subplots(4, 4, figsize=(10, 10))
rata2_accuracy = (df_test['Target'] == df_test['Predicted']).mean() * 100

for i, axi in enumerate(ax.flat):
    p0 = df_test['Proba_0'].values[i]
    p1 = df_test['Proba_1'].values[i]
    predicted_class = df_plot['Predicted'].values[i]
    prediction_probability = max(p0, p1) * 100
    true_class = df_plot['Target'].values[i]
    pixels = df_plot[[f'pixel{j}' for j in range(1, 28*28 + 1)]].values[i].reshape(28, 28)
    axi.imshow(pixels, cmap='viridis')
    axi.set(xticks=[], yticks=[],
            xlabel=f"True: {true_class}\nPred: {predicted_class}\nProb: {prediction_probability:.2f}%")
    edge_color = 'green' if predicted_class == true_class else 'red'
    for spine in axi.spines.values():
        spine.set_edgecolor(edge_color)
        spine.set_linewidth(3)

fig.suptitle(f'Contoh gambar yang diklasifikasikan dari set pengujian\n'
             f'Batas hijau: klasifikasi benar\nAkurasi Keseluruhan: {rata2_accuracy:.2f}%')
fig.tight_layout()
plt.show()
# Out:
# Iteration 1, loss = 1.34191046
# Validation score: 0.725000
# Iteration 2, loss = 0.66035880
# Validation score: 0.723958
# Iteration 3, loss = 0.56137001
# Validation score: 0.802083
# Iteration 4, loss = 0.48253049
# Validation score: 0.818750
# Iteration 5, loss = 0.44854942
# Validation score: 0.829167
# Iteration 6, loss = 0.41271404
# Validation score: 0.815625
# Iteration 7, loss = 0.39870363
# Validation score: 0.813542
# Iteration 8, loss = 0.41332541
# Validation score: 0.815625
# Iteration 9, loss = 0.36154238
# Validation score: 0.834375
# Iteration 10, loss = 0.32895535
# Validation score: 0.833333
# Iteration 11, loss = 0.31210217
# Validation score: 0.839583
# Iteration 12, loss = 0.29794544
# Validation score: 0.838542
# Iteration 13, loss = 0.28863157
# Validation score: 0.822917
# Iteration 14, loss = 0.30275731
# Validation score: 0.843750
# Iteration 15, loss = 0.26554316
# Validation score: 0.816667
# Iteration 16, loss = 0.27543562
# Validation score: 0.825000
# Iteration 17, loss = 0.24677245
# Validation score: 0.844792
# Iteration 18, loss = 0.22368618
# Validation score: 0.843750
# Iteration 19, loss = 0.22995336
# Validation score: 0.835417
# Iteration 20, loss = 0.21138772
# Validation score: 0.837500
# Iteration 21, loss = 0.20096662
# Validation score: 0.841667
# Iteration 22, loss = 0.20114068
# Validation score: 0.837500
# Iteration 23, loss = 0.18567076
# Validation score: 0.837500
# Iteration 24, loss = 0.18281406
# Validation score: 0.839583
# Iteration 25, loss = 0.17562612
# Validation score: 0.836458
# Iteration 26, loss = 0.16064232
# Validation score: 0.835417
# Iteration 27, loss = 0.15190583
# Validation score: 0.842708
# Iteration 28, loss = 0.14869294
# Validation score: 0.847917
# Iteration 29, loss = 0.14823299
# Validation score: 0.843750
# Iteration 30, loss = 0.12995215
# Validation score: 0.843750
# Iteration 31, loss = 0.12456835
# Validation score: 0.842708
# Iteration 32, loss = 0.12589548
# Validation score: 0.838542
# Iteration 33, loss = 0.14408992
# Validation score: 0.843750
# Iteration 34, loss = 0.13603784
# Validation score: 0.846875
# Iteration 35, loss = 0.11002876
# Validation score: 0.843750
# Iteration 36, loss = 0.10315460
# Validation score: 0.841667
# Iteration 37, loss = 0.10533226
# Validation score: 0.833333
# Iteration 38, loss = 0.09907548
# Validation score: 0.851042
# Iteration 39, loss = 0.09147732
# Validation score: 0.840625
# Iteration 40, loss = 0.08480173
# Validation score: 0.840625
# Iteration 41, loss = 0.08385885
# Validation score: 0.844792
# Iteration 42, loss = 0.07927240
# Validation score: 0.848958
# Iteration 43, loss = 0.06177153
# Validation score: 0.852083
# Iteration 44, loss = 0.06950852
# Validation score: 0.845833
# Iteration 45, loss = 0.06345109
# Validation score: 0.835417
# Iteration 46, loss = 0.06182861
# Validation score: 0.840625
# Iteration 47, loss = 0.05637608
# Validation score: 0.846875
# Iteration 48, loss = 0.05303785
# Validation score: 0.846875
# Iteration 49, loss = 0.05917240
# Validation score: 0.837500
# Iteration 50, loss = 0.05439444
# Validation score: 0.851042
# Iteration 51, loss = 0.06398525
# Validation score: 0.842708
# Iteration 52, loss = 0.05952717
# Validation score: 0.847917
# Iteration 53, loss = 0.05050734
# Validation score: 0.845833
# Iteration 54, loss = 0.07713775
# Validation score: 0.842708
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.34191046
# Validation score: 0.725000
# Iteration 2, loss = 0.66035880
# Validation score: 0.723958
# Iteration 3, loss = 0.56137001
# Validation score: 0.802083
# Iteration 4, loss = 0.48253049
# Validation score: 0.818750
# Iteration 5, loss = 0.44854942
# Validation score: 0.829167
# Iteration 6, loss = 0.41271404
# Validation score: 0.815625
# Iteration 7, loss = 0.39870363
# Validation score: 0.813542
# Iteration 8, loss = 0.41332541
# Validation score: 0.815625
# Iteration 9, loss = 0.36154238
# Validation score: 0.834375
# Iteration 10, loss = 0.32895535
# Validation score: 0.833333
# Iteration 11, loss = 0.31210217
# Validation score: 0.839583
# Iteration 12, loss = 0.29794544
# Validation score: 0.838542
# Iteration 13, loss = 0.28863157
# Validation score: 0.822917
# Iteration 14, loss = 0.30275731
# Validation score: 0.843750
# Iteration 15, loss = 0.26554316
# Validation score: 0.816667
# Iteration 16, loss = 0.27543562
# Validation score: 0.825000
# Iteration 17, loss = 0.24677245
# Validation score: 0.844792
# Iteration 18, loss = 0.22368618
# Validation score: 0.843750
# Iteration 19, loss = 0.22995336
# Validation score: 0.835417
# Iteration 20, loss = 0.21138772
# Validation score: 0.837500
# Iteration 21, loss = 0.20096662
# Validation score: 0.841667
# Iteration 22, loss = 0.20114068
# Validation score: 0.837500
# Iteration 23, loss = 0.18567076
# Validation score: 0.837500
# Iteration 24, loss = 0.18281406
# Validation score: 0.839583
# Iteration 25, loss = 0.17562612
# Validation score: 0.836458
# Iteration 26, loss = 0.16064232
# Validation score: 0.835417
# Iteration 27, loss = 0.15190583
# Validation score: 0.842708
# Iteration 28, loss = 0.14869294
# Validation score: 0.847917
# Iteration 29, loss = 0.14823299
# Validation score: 0.843750
# Iteration 30, loss = 0.12995215
# Validation score: 0.843750
# Iteration 31, loss = 0.12456835
# Validation score: 0.842708
# Iteration 32, loss = 0.12589548
# Validation score: 0.838542
# Iteration 33, loss = 0.14408992
# Validation score: 0.843750
# Iteration 34, loss = 0.13603784
# Validation score: 0.846875
# Iteration 35, loss = 0.11002876
# Validation score: 0.843750
# Iteration 36, loss = 0.10315460
# Validation score: 0.841667
# Iteration 37, loss = 0.10533226
# Validation score: 0.833333
# Iteration 38, loss = 0.09907548
# Validation score: 0.851042
# Iteration 39, loss = 0.09147732
# Validation score: 0.840625
# Iteration 40, loss = 0.08480173
# Validation score: 0.840625
# Iteration 41, loss = 0.08385885
# Validation score: 0.844792
# Iteration 42, loss = 0.07927240
# Validation score: 0.848958
# Iteration 43, loss = 0.06177153
# Validation score: 0.852083
# Iteration 44, loss = 0.06950852
# Validation score: 0.845833
# Iteration 45, loss = 0.06345109
# Validation score: 0.835417
# Iteration 46, loss = 0.06182861
# Validation score: 0.840625
# Iteration 47, loss = 0.05637608
# Validation score: 0.846875
# Iteration 48, loss = 0.05303785
# Validation score: 0.846875
# Iteration 49, loss = 0.05917240
# Validation score: 0.837500
# Iteration 50, loss = 0.05439444
# Validation score: 0.851042
# Iteration 51, loss = 0.06398525
# Validation score: 0.842708
# Iteration 52, loss = 0.05952717
# Validation score: 0.847917
# Iteration 53, loss = 0.05050734
# Validation score: 0.845833
# Iteration 54, loss = 0.07713775
# Validation score: 0.842708
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.34191046
# Validation score: 0.725000
# Iteration 2, loss = 0.66035880
# Validation score: 0.723958
# Iteration 3, loss = 0.56137001
# Validation score: 0.802083
# Iteration 4, loss = 0.48253049
# Validation score: 0.818750
# Iteration 5, loss = 0.44854942
# Validation score: 0.829167
# Iteration 6, loss = 0.41271404
# Validation score: 0.815625
# Iteration 7, loss = 0.39870363
# Validation score: 0.813542
# Iteration 8, loss = 0.41332541
# Validation score: 0.815625
# Iteration 9, loss = 0.36154238
# Validation score: 0.834375
# Iteration 10, loss = 0.32895535
# Validation score: 0.833333
# Iteration 11, loss = 0.31210217
# Validation score: 0.839583
# Iteration 12, loss = 0.29794544
# Validation score: 0.838542
# Iteration 13, loss = 0.28863157
# Validation score: 0.822917
# Iteration 14, loss = 0.30275731
# Validation score: 0.843750
# Iteration 15, loss = 0.26554316
# Validation score: 0.816667
# Iteration 16, loss = 0.27543562
# Validation score: 0.825000
# Iteration 17, loss = 0.24677245
# Validation score: 0.844792
# Iteration 18, loss = 0.22368618
# Validation score: 0.843750
# Iteration 19, loss = 0.22995336
# Validation score: 0.835417
# Iteration 20, loss = 0.21138772
# Validation score: 0.837500
# Iteration 21, loss = 0.20096662
# Validation score: 0.841667
# Iteration 22, loss = 0.20114068
# Validation score: 0.837500
# Iteration 23, loss = 0.18567076
# Validation score: 0.837500
# Iteration 24, loss = 0.18281406
# Validation score: 0.839583
# Iteration 25, loss = 0.17562612
# Validation score: 0.836458
# Iteration 26, loss = 0.16064232
# Validation score: 0.835417
# Iteration 27, loss = 0.15190583
# Validation score: 0.842708
# Iteration 28, loss = 0.14869294
# Validation score: 0.847917
# Iteration 29, loss = 0.14823299
# Validation score: 0.843750
# Iteration 30, loss = 0.12995215
# Validation score: 0.843750
# Iteration 31, loss = 0.12456835
# Validation score: 0.842708
# Iteration 32, loss = 0.12589548
# Validation score: 0.838542
# Iteration 33, loss = 0.14408992
# Validation score: 0.843750
# Iteration 34, loss = 0.13603784
# Validation score: 0.846875
# Iteration 35, loss = 0.11002876
# Validation score: 0.843750
# Iteration 36, loss = 0.10315460
# Validation score: 0.841667
# Iteration 37, loss = 0.10533226
# Validation score: 0.833333
# Iteration 38, loss = 0.09907548
# Validation score: 0.851042
# Iteration 39, loss = 0.09147732
# Validation score: 0.840625
# Iteration 40, loss = 0.08480173
# Validation score: 0.840625
# Iteration 41, loss = 0.08385885
# Validation score: 0.844792
# Iteration 42, loss = 0.07927240
# Validation score: 0.848958
# Iteration 43, loss = 0.06177153
# Validation score: 0.852083
# Iteration 44, loss = 0.06950852
# Validation score: 0.845833
# Iteration 45, loss = 0.06345109
# Validation score: 0.835417
# Iteration 46, loss = 0.06182861
# Validation score: 0.840625
# Iteration 47, loss = 0.05637608
# Validation score: 0.846875
# Iteration 48, loss = 0.05303785
# Validation score: 0.846875
# Iteration 49, loss = 0.05917240
# Validation score: 0.837500
# Iteration 50, loss = 0.05439444
# Validation score: 0.851042
# Iteration 51, loss = 0.06398525
# Validation score: 0.842708
# Iteration 52, loss = 0.05952717
# Validation score: 0.847917
# Iteration 53, loss = 0.05050734
# Validation score: 0.845833
# Iteration 54, loss = 0.07713775
# Validation score: 0.842708
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.03858787
# Validation score: 0.758854
# Iteration 2, loss = 0.56846479
# Validation score: 0.811458
# Iteration 3, loss = 0.48276995
# Validation score: 0.802083
# Iteration 4, loss = 0.44348819
# Validation score: 0.830208
# Iteration 5, loss = 0.41174877
# Validation score: 0.824479
# Iteration 6, loss = 0.38217373
# Validation score: 0.839063
# Iteration 7, loss = 0.36126286
# Validation score: 0.835938
# Iteration 8, loss = 0.35633136
# Validation score: 0.840625
# Iteration 9, loss = 0.32500730
# Validation score: 0.841146
# Iteration 10, loss = 0.30725796
# Validation score: 0.837500
# Iteration 11, loss = 0.30886007
# Validation score: 0.847396
# Iteration 12, loss = 0.29062643
# Validation score: 0.846875
# Iteration 13, loss = 0.29263162
# Validation score: 0.858333
# Iteration 14, loss = 0.25607580
# Validation score: 0.859896
# Iteration 15, loss = 0.24413679
# Validation score: 0.863542
# Iteration 16, loss = 0.24097543
# Validation score: 0.850000
# Iteration 17, loss = 0.22278311
# Validation score: 0.857292
# Iteration 18, loss = 0.21516859
# Validation score: 0.852083
# Iteration 19, loss = 0.20564591
# Validation score: 0.853125
# Iteration 20, loss = 0.21509785
# Validation score: 0.861979
# Iteration 21, loss = 0.19134615
# Validation score: 0.861458
# Iteration 22, loss = 0.18785398
# Validation score: 0.845313
# Iteration 23, loss = 0.18500709
# Validation score: 0.849479
# Iteration 24, loss = 0.17773174
# Validation score: 0.850000
# Iteration 25, loss = 0.19341098
# Validation score: 0.851562
# Iteration 26, loss = 0.16661489
# Validation score: 0.865104
# Iteration 27, loss = 0.14099944
# Validation score: 0.863542
# Iteration 28, loss = 0.15862817
# Validation score: 0.860938
# Iteration 29, loss = 0.17592838
# Validation score: 0.858333
# Iteration 30, loss = 0.13528725
# Validation score: 0.861458
# Iteration 31, loss = 0.12847063
# Validation score: 0.860417
# Iteration 32, loss = 0.13127734
# Validation score: 0.861458
# Iteration 33, loss = 0.11525629
# Validation score: 0.862500
# Iteration 34, loss = 0.11686948
# Validation score: 0.852604
# Iteration 35, loss = 0.10394636
# Validation score: 0.852604
# Iteration 36, loss = 0.11658521
# Validation score: 0.850000
# Iteration 37, loss = 0.11991949
# Validation score: 0.846354
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.90807088
# Validation score: 0.795139
# Iteration 2, loss = 0.53022724
# Validation score: 0.813542
# Iteration 3, loss = 0.46160454
# Validation score: 0.819792
# Iteration 4, loss = 0.42130832
# Validation score: 0.832986
# Iteration 5, loss = 0.38943633
# Validation score: 0.838194
# Iteration 6, loss = 0.36397516
# Validation score: 0.836111
# Iteration 7, loss = 0.34521918
# Validation score: 0.844097
# Iteration 8, loss = 0.33199598
# Validation score: 0.840278
# Iteration 9, loss = 0.31604620
# Validation score: 0.840972
# Iteration 10, loss = 0.31286849
# Validation score: 0.848611
# Iteration 11, loss = 0.28978030
# Validation score: 0.851736
# Iteration 12, loss = 0.27809250
# Validation score: 0.853125
# Iteration 13, loss = 0.27266406
# Validation score: 0.855208
# Iteration 14, loss = 0.25226965
# Validation score: 0.857639
# Iteration 15, loss = 0.24021611
# Validation score: 0.861806
# Iteration 16, loss = 0.22420121
# Validation score: 0.862847
# Iteration 17, loss = 0.22268372
# Validation score: 0.853472
# Iteration 18, loss = 0.21965237
# Validation score: 0.859722
# Iteration 19, loss = 0.20368196
# Validation score: 0.849653
# Iteration 20, loss = 0.20302633
# Validation score: 0.849653
# Iteration 21, loss = 0.19209851
# Validation score: 0.856944
# Iteration 22, loss = 0.19259728
# Validation score: 0.843750
# Iteration 23, loss = 0.17864561
# Validation score: 0.855903
# Iteration 24, loss = 0.17195989
# Validation score: 0.859028
# Iteration 25, loss = 0.16094505
# Validation score: 0.861806
# Iteration 26, loss = 0.15705549
# Validation score: 0.854861
# Iteration 27, loss = 0.15499506
# Validation score: 0.856944
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.05168604
# Validation score: 0.750000
# Iteration 2, loss = 0.56777405
# Validation score: 0.808333
# Iteration 3, loss = 0.49178766
# Validation score: 0.817187
# Iteration 4, loss = 0.44642927
# Validation score: 0.812500
# Iteration 5, loss = 0.43158050
# Validation score: 0.834896
# Iteration 6, loss = 0.38960407
# Validation score: 0.838021
# Iteration 7, loss = 0.38826858
# Validation score: 0.840104
# Iteration 8, loss = 0.35253905
# Validation score: 0.835938
# Iteration 9, loss = 0.34729639
# Validation score: 0.847396
# Iteration 10, loss = 0.33385867
# Validation score: 0.846875
# Iteration 11, loss = 0.31501860
# Validation score: 0.839063
# Iteration 12, loss = 0.29892364
# Validation score: 0.832292
# Iteration 13, loss = 0.29838923
# Validation score: 0.851562
# Iteration 14, loss = 0.28577476
# Validation score: 0.834375
# Iteration 15, loss = 0.26749964
# Validation score: 0.849479
# Iteration 16, loss = 0.25105601
# Validation score: 0.855729
# Iteration 17, loss = 0.24319607
# Validation score: 0.844792
# Iteration 18, loss = 0.24300662
# Validation score: 0.845833
# Iteration 19, loss = 0.23760712
# Validation score: 0.855729
# Iteration 20, loss = 0.22140374
# Validation score: 0.848958
# Iteration 21, loss = 0.21218687
# Validation score: 0.854688
# Iteration 22, loss = 0.19396075
# Validation score: 0.861458
# Iteration 23, loss = 0.18665245
# Validation score: 0.847917
# Iteration 24, loss = 0.18406300
# Validation score: 0.855208
# Iteration 25, loss = 0.18880519
# Validation score: 0.857292
# Iteration 26, loss = 0.17738962
# Validation score: 0.856250
# Iteration 27, loss = 0.17111414
# Validation score: 0.850521
# Iteration 28, loss = 0.15760241
# Validation score: 0.851042
# Iteration 29, loss = 0.16049058
# Validation score: 0.860417
# Iteration 30, loss = 0.14618663
# Validation score: 0.863542
# Iteration 31, loss = 0.13699917
# Validation score: 0.853646
# Iteration 32, loss = 0.14454451
# Validation score: 0.833854
# Iteration 33, loss = 0.13649360
# Validation score: 0.861458
# Iteration 34, loss = 0.12397107
# Validation score: 0.853125
# Iteration 35, loss = 0.11881903
# Validation score: 0.845833
# Iteration 36, loss = 0.12299561
# Validation score: 0.845313
# Iteration 37, loss = 0.11623110
# Validation score: 0.855729
# Iteration 38, loss = 0.10832304
# Validation score: 0.857292
# Iteration 39, loss = 0.10373705
# Validation score: 0.857292
# Iteration 40, loss = 0.09529691
# Validation score: 0.861458
# Iteration 41, loss = 0.09346059
# Validation score: 0.853646
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.03858787
# Validation score: 0.758854
# Iteration 2, loss = 0.56846479
# Validation score: 0.811458
# Iteration 3, loss = 0.48276995
# Validation score: 0.802083
# Iteration 4, loss = 0.44348819
# Validation score: 0.830208
# Iteration 5, loss = 0.41174877
# Validation score: 0.824479
# Iteration 6, loss = 0.38217373
# Validation score: 0.839063
# Iteration 7, loss = 0.36126286
# Validation score: 0.835938
# Iteration 8, loss = 0.35633136
# Validation score: 0.840625
# Iteration 9, loss = 0.32500730
# Validation score: 0.841146
# Iteration 10, loss = 0.30725796
# Validation score: 0.837500
# Iteration 11, loss = 0.30886007
# Validation score: 0.847396
# Iteration 12, loss = 0.29062643
# Validation score: 0.846875
# Iteration 13, loss = 0.29263162
# Validation score: 0.858333
# Iteration 14, loss = 0.25607580
# Validation score: 0.859896
# Iteration 15, loss = 0.24413679
# Validation score: 0.863542
# Iteration 16, loss = 0.24097543
# Validation score: 0.850000
# Iteration 17, loss = 0.22278311
# Validation score: 0.857292
# Iteration 18, loss = 0.21516859
# Validation score: 0.852083
# Iteration 19, loss = 0.20564591
# Validation score: 0.853125
# Iteration 20, loss = 0.21509785
# Validation score: 0.861979
# Iteration 21, loss = 0.19134615
# Validation score: 0.861458
# Iteration 22, loss = 0.18785398
# Validation score: 0.845313
# Iteration 23, loss = 0.18500709
# Validation score: 0.849479
# Iteration 24, loss = 0.17773174
# Validation score: 0.850000
# Iteration 25, loss = 0.19341098
# Validation score: 0.851562
# Iteration 26, loss = 0.16661489
# Validation score: 0.865104
# Iteration 27, loss = 0.14099944
# Validation score: 0.863542
# Iteration 28, loss = 0.15862817
# Validation score: 0.860938
# Iteration 29, loss = 0.17592838
# Validation score: 0.858333
# Iteration 30, loss = 0.13528725
# Validation score: 0.861458
# Iteration 31, loss = 0.12847063
# Validation score: 0.860417
# Iteration 32, loss = 0.13127734
# Validation score: 0.861458
# Iteration 33, loss = 0.11525629
# Validation score: 0.862500
# Iteration 34, loss = 0.11686948
# Validation score: 0.852604
# Iteration 35, loss = 0.10394636
# Validation score: 0.852604
# Iteration 36, loss = 0.11658521
# Validation score: 0.850000
# Iteration 37, loss = 0.11991949
# Validation score: 0.846354
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.03858787
# Validation score: 0.758854
# Iteration 2, loss = 0.56846479
# Validation score: 0.811458
# Iteration 3, loss = 0.48276995
# Validation score: 0.802083
# Iteration 4, loss = 0.44348819
# Validation score: 0.830208
# Iteration 5, loss = 0.41174877
# Validation score: 0.824479
# Iteration 6, loss = 0.38217373
# Validation score: 0.839063
# Iteration 7, loss = 0.36126286
# Validation score: 0.835938
# Iteration 8, loss = 0.35633136
# Validation score: 0.840625
# Iteration 9, loss = 0.32500730
# Validation score: 0.841146
# Iteration 10, loss = 0.30725796
# Validation score: 0.837500
# Iteration 11, loss = 0.30886007
# Validation score: 0.847396
# Iteration 12, loss = 0.29062643
# Validation score: 0.846875
# Iteration 13, loss = 0.29263162
# Validation score: 0.858333
# Iteration 14, loss = 0.25607580
# Validation score: 0.859896
# Iteration 15, loss = 0.24413679
# Validation score: 0.863542
# Iteration 16, loss = 0.24097543
# Validation score: 0.850000
# Iteration 17, loss = 0.22278311
# Validation score: 0.857292
# Iteration 18, loss = 0.21516859
# Validation score: 0.852083
# Iteration 19, loss = 0.20564591
# Validation score: 0.853125
# Iteration 20, loss = 0.21509785
# Validation score: 0.861979
# Iteration 21, loss = 0.19134615
# Validation score: 0.861458
# Iteration 22, loss = 0.18785398
# Validation score: 0.845313
# Iteration 23, loss = 0.18500709
# Validation score: 0.849479
# Iteration 24, loss = 0.17773174
# Validation score: 0.850000
# Iteration 25, loss = 0.19341098
# Validation score: 0.851562
# Iteration 26, loss = 0.16661489
# Validation score: 0.865104
# Iteration 27, loss = 0.14099944
# Validation score: 0.863542
# Iteration 28, loss = 0.15862817
# Validation score: 0.860938
# Iteration 29, loss = 0.17592838
# Validation score: 0.858333
# Iteration 30, loss = 0.13528725
# Validation score: 0.861458
# Iteration 31, loss = 0.12847063
# Validation score: 0.860417
# Iteration 32, loss = 0.13127734
# Validation score: 0.861458
# Iteration 33, loss = 0.11525629
# Validation score: 0.862500
# Iteration 34, loss = 0.11686948
# Validation score: 0.852604
# Iteration 35, loss = 0.10394636
# Validation score: 0.852604
# Iteration 36, loss = 0.11658521
# Validation score: 0.850000
# Iteration 37, loss = 0.11991949
# Validation score: 0.846354
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.76666119
# Validation score: 0.808542
# Iteration 2, loss = 0.47341390
# Validation score: 0.838958
# Iteration 3, loss = 0.41168389
# Validation score: 0.842708
# Iteration 4, loss = 0.38168389
# Validation score: 0.852917
# Iteration 5, loss = 0.35707779
# Validation score: 0.839375
# Iteration 6, loss = 0.33487588
# Validation score: 0.858750
# Iteration 7, loss = 0.31278931
# Validation score: 0.856667
# Iteration 8, loss = 0.29656905
# Validation score: 0.869792
# Iteration 9, loss = 0.28882931
# Validation score: 0.856250
# Iteration 10, loss = 0.27209024
# Validation score: 0.865833
# Iteration 11, loss = 0.26184610
# Validation score: 0.862708
# Iteration 12, loss = 0.25300122
# Validation score: 0.867708
# Iteration 13, loss = 0.23429409
# Validation score: 0.871875
# Iteration 14, loss = 0.22800019
# Validation score: 0.860625
# Iteration 15, loss = 0.23186730
# Validation score: 0.867083
# Iteration 16, loss = 0.21333891
# Validation score: 0.874375
# Iteration 17, loss = 0.20461490
# Validation score: 0.866875
# Iteration 18, loss = 0.20283301
# Validation score: 0.860833
# Iteration 19, loss = 0.19271938
# Validation score: 0.872083
# Iteration 20, loss = 0.19060591
# Validation score: 0.864583
# Iteration 21, loss = 0.18033625
# Validation score: 0.865833
# Iteration 22, loss = 0.17765042
# Validation score: 0.870000
# Iteration 23, loss = 0.16542566
# Validation score: 0.871875
# Iteration 24, loss = 0.16080771
# Validation score: 0.869167
# Iteration 25, loss = 0.15777872
# Validation score: 0.866875
# Iteration 26, loss = 0.15011291
# Validation score: 0.867708
# Iteration 27, loss = 0.14765918
# Validation score: 0.869167
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.91623148
# Validation score: 0.761111
# Iteration 2, loss = 0.52147001
# Validation score: 0.815625
# Iteration 3, loss = 0.45793494
# Validation score: 0.829861
# Iteration 4, loss = 0.41251830
# Validation score: 0.839236
# Iteration 5, loss = 0.39799100
# Validation score: 0.848264
# Iteration 6, loss = 0.36561190
# Validation score: 0.853125
# Iteration 7, loss = 0.34902236
# Validation score: 0.854167
# Iteration 8, loss = 0.33001103
# Validation score: 0.858333
# Iteration 9, loss = 0.31006737
# Validation score: 0.863194
# Iteration 10, loss = 0.30610290
# Validation score: 0.861111
# Iteration 11, loss = 0.29270815
# Validation score: 0.863889
# Iteration 12, loss = 0.27366200
# Validation score: 0.856250
# Iteration 13, loss = 0.27231270
# Validation score: 0.863194
# Iteration 14, loss = 0.24777717
# Validation score: 0.859028
# Iteration 15, loss = 0.24456644
# Validation score: 0.851736
# Iteration 16, loss = 0.23582611
# Validation score: 0.850694
# Iteration 17, loss = 0.23651474
# Validation score: 0.864931
# Iteration 18, loss = 0.21868981
# Validation score: 0.865278
# Iteration 19, loss = 0.22861816
# Validation score: 0.865625
# Iteration 20, loss = 0.20210144
# Validation score: 0.868056
# Iteration 21, loss = 0.19365479
# Validation score: 0.860764
# Iteration 22, loss = 0.18679137
# Validation score: 0.872569
# Iteration 23, loss = 0.17550312
# Validation score: 0.861111
# Iteration 24, loss = 0.18492200
# Validation score: 0.865972
# Iteration 25, loss = 0.17822488
# Validation score: 0.861806
# Iteration 26, loss = 0.15910207
# Validation score: 0.865278
# Iteration 27, loss = 0.15144357
# Validation score: 0.864931
# Iteration 28, loss = 0.15489702
# Validation score: 0.864583
# Iteration 29, loss = 0.14443417
# Validation score: 0.865625
# Iteration 30, loss = 0.13597928
# Validation score: 0.868403
# Iteration 31, loss = 0.14741713
# Validation score: 0.860764
# Iteration 32, loss = 0.13645935
# Validation score: 0.860069
# Iteration 33, loss = 0.12659503
# Validation score: 0.862847
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.03858787
# Validation score: 0.758854
# Iteration 2, loss = 0.56846479
# Validation score: 0.811458
# Iteration 3, loss = 0.48276995
# Validation score: 0.802083
# Iteration 4, loss = 0.44348819
# Validation score: 0.830208
# Iteration 5, loss = 0.41174877
# Validation score: 0.824479
# Iteration 6, loss = 0.38217373
# Validation score: 0.839063
# Iteration 7, loss = 0.36126286
# Validation score: 0.835938
# Iteration 8, loss = 0.35633136
# Validation score: 0.840625
# Iteration 9, loss = 0.32500730
# Validation score: 0.841146
# Iteration 10, loss = 0.30725796
# Validation score: 0.837500
# Iteration 11, loss = 0.30886007
# Validation score: 0.847396
# Iteration 12, loss = 0.29062643
# Validation score: 0.846875
# Iteration 13, loss = 0.29263162
# Validation score: 0.858333
# Iteration 14, loss = 0.25607580
# Validation score: 0.859896
# Iteration 15, loss = 0.24413679
# Validation score: 0.863542
# Iteration 16, loss = 0.24097543
# Validation score: 0.850000
# Iteration 17, loss = 0.22278311
# Validation score: 0.857292
# Iteration 18, loss = 0.21516859
# Validation score: 0.852083
# Iteration 19, loss = 0.20564591
# Validation score: 0.853125
# Iteration 20, loss = 0.21509785
# Validation score: 0.861979
# Iteration 21, loss = 0.19134615
# Validation score: 0.861458
# Iteration 22, loss = 0.18785398
# Validation score: 0.845313
# Iteration 23, loss = 0.18500709
# Validation score: 0.849479
# Iteration 24, loss = 0.17773174
# Validation score: 0.850000
# Iteration 25, loss = 0.19341098
# Validation score: 0.851562
# Iteration 26, loss = 0.16661489
# Validation score: 0.865104
# Iteration 27, loss = 0.14099944
# Validation score: 0.863542
# Iteration 28, loss = 0.15862817
# Validation score: 0.860938
# Iteration 29, loss = 0.17592838
# Validation score: 0.858333
# Iteration 30, loss = 0.13528725
# Validation score: 0.861458
# Iteration 31, loss = 0.12847063
# Validation score: 0.860417
# Iteration 32, loss = 0.13127734
# Validation score: 0.861458
# Iteration 33, loss = 0.11525629
# Validation score: 0.862500
# Iteration 34, loss = 0.11686948
# Validation score: 0.852604
# Iteration 35, loss = 0.10394636
# Validation score: 0.852604
# Iteration 36, loss = 0.11658521
# Validation score: 0.850000
# Iteration 37, loss = 0.11991949
# Validation score: 0.846354
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.91623148
# Validation score: 0.761111
# Iteration 2, loss = 0.52147001
# Validation score: 0.815625
# Iteration 3, loss = 0.45793494
# Validation score: 0.829861
# Iteration 4, loss = 0.41251830
# Validation score: 0.839236
# Iteration 5, loss = 0.39799100
# Validation score: 0.848264
# Iteration 6, loss = 0.36561190
# Validation score: 0.853125
# Iteration 7, loss = 0.34902236
# Validation score: 0.854167
# Iteration 8, loss = 0.33001103
# Validation score: 0.858333
# Iteration 9, loss = 0.31006737
# Validation score: 0.863194
# Iteration 10, loss = 0.30610290
# Validation score: 0.861111
# Iteration 11, loss = 0.29270815
# Validation score: 0.863889
# Iteration 12, loss = 0.27366200
# Validation score: 0.856250
# Iteration 13, loss = 0.27231270
# Validation score: 0.863194
# Iteration 14, loss = 0.24777717
# Validation score: 0.859028
# Iteration 15, loss = 0.24456644
# Validation score: 0.851736
# Iteration 16, loss = 0.23582611
# Validation score: 0.850694
# Iteration 17, loss = 0.23651474
# Validation score: 0.864931
# Iteration 18, loss = 0.21868981
# Validation score: 0.865278
# Iteration 19, loss = 0.22861816
# Validation score: 0.865625
# Iteration 20, loss = 0.20210144
# Validation score: 0.868056
# Iteration 21, loss = 0.19365479
# Validation score: 0.860764
# Iteration 22, loss = 0.18679137
# Validation score: 0.872569
# Iteration 23, loss = 0.17550312
# Validation score: 0.861111
# Iteration 24, loss = 0.18492200
# Validation score: 0.865972
# Iteration 25, loss = 0.17822488
# Validation score: 0.861806
# Iteration 26, loss = 0.15910207
# Validation score: 0.865278
# Iteration 27, loss = 0.15144357
# Validation score: 0.864931
# Iteration 28, loss = 0.15489702
# Validation score: 0.864583
# Iteration 29, loss = 0.14443417
# Validation score: 0.865625
# Iteration 30, loss = 0.13597928
# Validation score: 0.868403
# Iteration 31, loss = 0.14741713
# Validation score: 0.860764
# Iteration 32, loss = 0.13645935
# Validation score: 0.860069
# Iteration 33, loss = 0.12659503
# Validation score: 0.862847
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.91039996
# Validation score: 0.766667
# Iteration 2, loss = 0.51621510
# Validation score: 0.823958
# Iteration 3, loss = 0.47407225
# Validation score: 0.830903
# Iteration 4, loss = 0.41837121
# Validation score: 0.846528
# Iteration 5, loss = 0.38566328
# Validation score: 0.849306
# Iteration 6, loss = 0.36318540
# Validation score: 0.857986
# Iteration 7, loss = 0.34026310
# Validation score: 0.851389
# Iteration 8, loss = 0.32271287
# Validation score: 0.866667
# Iteration 9, loss = 0.30837413
# Validation score: 0.864236
# Iteration 10, loss = 0.30682099
# Validation score: 0.867361
# Iteration 11, loss = 0.28862081
# Validation score: 0.859722
# Iteration 12, loss = 0.28087227
# Validation score: 0.862153
# Iteration 13, loss = 0.27152587
# Validation score: 0.863194
# Iteration 14, loss = 0.24737479
# Validation score: 0.871875
# Iteration 15, loss = 0.23804759
# Validation score: 0.858333
# Iteration 16, loss = 0.22597746
# Validation score: 0.856944
# Iteration 17, loss = 0.23139323
# Validation score: 0.864236
# Iteration 18, loss = 0.21532578
# Validation score: 0.869444
# Iteration 19, loss = 0.21776574
# Validation score: 0.860069
# Iteration 20, loss = 0.20053728
# Validation score: 0.871528
# Iteration 21, loss = 0.18738544
# Validation score: 0.873611
# Iteration 22, loss = 0.18930887
# Validation score: 0.878472
# Iteration 23, loss = 0.16809003
# Validation score: 0.862153
# Iteration 24, loss = 0.16977780
# Validation score: 0.858333
# Iteration 25, loss = 0.16419645
# Validation score: 0.866319
# Iteration 26, loss = 0.15319015
# Validation score: 0.875000
# Iteration 27, loss = 0.14629870
# Validation score: 0.855556
# Iteration 28, loss = 0.15056489
# Validation score: 0.872222
# Iteration 29, loss = 0.13400877
# Validation score: 0.869444
# Iteration 30, loss = 0.12771209
# Validation score: 0.872222
# Iteration 31, loss = 0.13147395
# Validation score: 0.869444
# Iteration 32, loss = 0.13604386
# Validation score: 0.857986
# Iteration 33, loss = 0.12803263
# Validation score: 0.868750
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.91623148
# Validation score: 0.761111
# Iteration 2, loss = 0.52147001
# Validation score: 0.815625
# Iteration 3, loss = 0.45793494
# Validation score: 0.829861
# Iteration 4, loss = 0.41251830
# Validation score: 0.839236
# Iteration 5, loss = 0.39799100
# Validation score: 0.848264
# Iteration 6, loss = 0.36561190
# Validation score: 0.853125
# Iteration 7, loss = 0.34902236
# Validation score: 0.854167
# Iteration 8, loss = 0.33001103
# Validation score: 0.858333
# Iteration 9, loss = 0.31006737
# Validation score: 0.863194
# Iteration 10, loss = 0.30610290
# Validation score: 0.861111
# Iteration 11, loss = 0.29270815
# Validation score: 0.863889
# Iteration 12, loss = 0.27366200
# Validation score: 0.856250
# Iteration 13, loss = 0.27231270
# Validation score: 0.863194
# Iteration 14, loss = 0.24777717
# Validation score: 0.859028
# Iteration 15, loss = 0.24456644
# Validation score: 0.851736
# Iteration 16, loss = 0.23582611
# Validation score: 0.850694
# Iteration 17, loss = 0.23651474
# Validation score: 0.864931
# Iteration 18, loss = 0.21868981
# Validation score: 0.865278
# Iteration 19, loss = 0.22861816
# Validation score: 0.865625
# Iteration 20, loss = 0.20210144
# Validation score: 0.868056
# Iteration 21, loss = 0.19365479
# Validation score: 0.860764
# Iteration 22, loss = 0.18679137
# Validation score: 0.872569
# Iteration 23, loss = 0.17550312
# Validation score: 0.861111
# Iteration 24, loss = 0.18492200
# Validation score: 0.865972
# Iteration 25, loss = 0.17822488
# Validation score: 0.861806
# Iteration 26, loss = 0.15910207
# Validation score: 0.865278
# Iteration 27, loss = 0.15144357
# Validation score: 0.864931
# Iteration 28, loss = 0.15489702
# Validation score: 0.864583
# Iteration 29, loss = 0.14443417
# Validation score: 0.865625
# Iteration 30, loss = 0.13597928
# Validation score: 0.868403
# Iteration 31, loss = 0.14741713
# Validation score: 0.860764
# Iteration 32, loss = 0.13645935
# Validation score: 0.860069
# Iteration 33, loss = 0.12659503
# Validation score: 0.862847
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.82868173
# Validation score: 0.810417
# Iteration 2, loss = 0.49691443
# Validation score: 0.832031
# Iteration 3, loss = 0.44059214
# Validation score: 0.830990
# Iteration 4, loss = 0.39510841
# Validation score: 0.848177
# Iteration 5, loss = 0.36967104
# Validation score: 0.855469
# Iteration 6, loss = 0.34319464
# Validation score: 0.856771
# Iteration 7, loss = 0.32700563
# Validation score: 0.864062
# Iteration 8, loss = 0.30565454
# Validation score: 0.864583
# Iteration 9, loss = 0.29883573
# Validation score: 0.869531
# Iteration 10, loss = 0.28203860
# Validation score: 0.869792
# Iteration 11, loss = 0.26743928
# Validation score: 0.864844
# Iteration 12, loss = 0.25739434
# Validation score: 0.867969
# Iteration 13, loss = 0.24471027
# Validation score: 0.875521
# Iteration 14, loss = 0.23864262
# Validation score: 0.869792
# Iteration 15, loss = 0.22980118
# Validation score: 0.870313
# Iteration 16, loss = 0.21545677
# Validation score: 0.870313
# Iteration 17, loss = 0.21278900
# Validation score: 0.864844
# Iteration 18, loss = 0.20717035
# Validation score: 0.869010
# Iteration 19, loss = 0.19493828
# Validation score: 0.872396
# Iteration 20, loss = 0.19142339
# Validation score: 0.870052
# Iteration 21, loss = 0.18050844
# Validation score: 0.874740
# Iteration 22, loss = 0.17234657
# Validation score: 0.876302
# Iteration 23, loss = 0.16268794
# Validation score: 0.870313
# Iteration 24, loss = 0.16329364
# Validation score: 0.870052
# Iteration 25, loss = 0.15418136
# Validation score: 0.871615
# Iteration 26, loss = 0.14568605
# Validation score: 0.864583
# Iteration 27, loss = 0.14722275
# Validation score: 0.867188
# Iteration 28, loss = 0.14079791
# Validation score: 0.874479
# Iteration 29, loss = 0.13926568
# Validation score: 0.871615
# Iteration 30, loss = 0.13571118
# Validation score: 0.868490
# Iteration 31, loss = 0.11640082
# Validation score: 0.872396
# Iteration 32, loss = 0.11581465
# Validation score: 0.873698
# Iteration 33, loss = 0.11132109
# Validation score: 0.877344
# Iteration 34, loss = 0.10657111
# Validation score: 0.875781
# Iteration 35, loss = 0.10392462
# Validation score: 0.876563
# Iteration 36, loss = 0.09690082
# Validation score: 0.861198
# Iteration 37, loss = 0.09912494
# Validation score: 0.870313
# Iteration 38, loss = 0.09729882
# Validation score: 0.871615
# Iteration 39, loss = 0.08277167
# Validation score: 0.872396
# Iteration 40, loss = 0.08071986
# Validation score: 0.861719
# Iteration 41, loss = 0.08948328
# Validation score: 0.869792
# Iteration 42, loss = 0.08089251
# Validation score: 0.876563
# Iteration 43, loss = 0.07751018
# Validation score: 0.861198
# Iteration 44, loss = 0.07735733
# Validation score: 0.876823
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.77144690
# Validation score: 0.817708
# Iteration 2, loss = 0.46628409
# Validation score: 0.827083
# Iteration 3, loss = 0.41973024
# Validation score: 0.838542
# Iteration 4, loss = 0.38045972
# Validation score: 0.855625
# Iteration 5, loss = 0.35184943
# Validation score: 0.850417
# Iteration 6, loss = 0.33766458
# Validation score: 0.848750
# Iteration 7, loss = 0.32471016
# Validation score: 0.864167
# Iteration 8, loss = 0.30478660
# Validation score: 0.869167
# Iteration 9, loss = 0.28779797
# Validation score: 0.869792
# Iteration 10, loss = 0.28074508
# Validation score: 0.862500
# Iteration 11, loss = 0.27120350
# Validation score: 0.878125
# Iteration 12, loss = 0.25564871
# Validation score: 0.874167
# Iteration 13, loss = 0.24837052
# Validation score: 0.873750
# Iteration 14, loss = 0.24082191
# Validation score: 0.870833
# Iteration 15, loss = 0.22271333
# Validation score: 0.876875
# Iteration 16, loss = 0.21524206
# Validation score: 0.875625
# Iteration 17, loss = 0.21134634
# Validation score: 0.873333
# Iteration 18, loss = 0.20170085
# Validation score: 0.873958
# Iteration 19, loss = 0.19188530
# Validation score: 0.877500
# Iteration 20, loss = 0.20003047
# Validation score: 0.858750
# Iteration 21, loss = 0.19131774
# Validation score: 0.874792
# Iteration 22, loss = 0.17389706
# Validation score: 0.872083
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.82210880
# Validation score: 0.816927
# Iteration 2, loss = 0.48701753
# Validation score: 0.837760
# Iteration 3, loss = 0.43926093
# Validation score: 0.846094
# Iteration 4, loss = 0.40325758
# Validation score: 0.861979
# Iteration 5, loss = 0.36677085
# Validation score: 0.866927
# Iteration 6, loss = 0.34238242
# Validation score: 0.867708
# Iteration 7, loss = 0.32367855
# Validation score: 0.872135
# Iteration 8, loss = 0.31241422
# Validation score: 0.874740
# Iteration 9, loss = 0.29309963
# Validation score: 0.867708
# Iteration 10, loss = 0.28347967
# Validation score: 0.877865
# Iteration 11, loss = 0.27128468
# Validation score: 0.878646
# Iteration 12, loss = 0.26050511
# Validation score: 0.874479
# Iteration 13, loss = 0.25469524
# Validation score: 0.881771
# Iteration 14, loss = 0.24315620
# Validation score: 0.878906
# Iteration 15, loss = 0.24076517
# Validation score: 0.878385
# Iteration 16, loss = 0.22155069
# Validation score: 0.877865
# Iteration 17, loss = 0.21773157
# Validation score: 0.884635
# Iteration 18, loss = 0.21330589
# Validation score: 0.881510
# Iteration 19, loss = 0.20050969
# Validation score: 0.877604
# Iteration 20, loss = 0.19368676
# Validation score: 0.881250
# Iteration 21, loss = 0.18703900
# Validation score: 0.881510
# Iteration 22, loss = 0.17795927
# Validation score: 0.880208
# Iteration 23, loss = 0.17346503
# Validation score: 0.889323
# Iteration 24, loss = 0.17182034
# Validation score: 0.882292
# Iteration 25, loss = 0.16643303
# Validation score: 0.880729
# Iteration 26, loss = 0.16966336
# Validation score: 0.879687
# Iteration 27, loss = 0.14465828
# Validation score: 0.876823
# Iteration 28, loss = 0.14663824
# Validation score: 0.882812
# Iteration 29, loss = 0.13675224
# Validation score: 0.881510
# Iteration 30, loss = 0.13637924
# Validation score: 0.883854
# Iteration 31, loss = 0.13553785
# Validation score: 0.876563
# Iteration 32, loss = 0.12732573
# Validation score: 0.868229
# Iteration 33, loss = 0.11853527
# Validation score: 0.884115
# Iteration 34, loss = 0.10946346
# Validation score: 0.883073
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.76666119
# Validation score: 0.808542
# Iteration 2, loss = 0.47341390
# Validation score: 0.838958
# Iteration 3, loss = 0.41168389
# Validation score: 0.842708
# Iteration 4, loss = 0.38168389
# Validation score: 0.852917
# Iteration 5, loss = 0.35707779
# Validation score: 0.839375
# Iteration 6, loss = 0.33487588
# Validation score: 0.858750
# Iteration 7, loss = 0.31278931
# Validation score: 0.856667
# Iteration 8, loss = 0.29656905
# Validation score: 0.869792
# Iteration 9, loss = 0.28882931
# Validation score: 0.856250
# Iteration 10, loss = 0.27209024
# Validation score: 0.865833
# Iteration 11, loss = 0.26184610
# Validation score: 0.862708
# Iteration 12, loss = 0.25300122
# Validation score: 0.867708
# Iteration 13, loss = 0.23429409
# Validation score: 0.871875
# Iteration 14, loss = 0.22800019
# Validation score: 0.860625
# Iteration 15, loss = 0.23186730
# Validation score: 0.867083
# Iteration 16, loss = 0.21333891
# Validation score: 0.874375
# Iteration 17, loss = 0.20461490
# Validation score: 0.866875
# Iteration 18, loss = 0.20283301
# Validation score: 0.860833
# Iteration 19, loss = 0.19271938
# Validation score: 0.872083
# Iteration 20, loss = 0.19060591
# Validation score: 0.864583
# Iteration 21, loss = 0.18033625
# Validation score: 0.865833
# Iteration 22, loss = 0.17765042
# Validation score: 0.870000
# Iteration 23, loss = 0.16542566
# Validation score: 0.871875
# Iteration 24, loss = 0.16080771
# Validation score: 0.869167
# Iteration 25, loss = 0.15777872
# Validation score: 0.866875
# Iteration 26, loss = 0.15011291
# Validation score: 0.867708
# Iteration 27, loss = 0.14765918
# Validation score: 0.869167
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.68772542
# Validation score: 0.830208
# Iteration 2, loss = 0.43773971
# Validation score: 0.857887
# Iteration 3, loss = 0.38996258
# Validation score: 0.848214
# Iteration 4, loss = 0.36421331
# Validation score: 0.861310
# Iteration 5, loss = 0.33779592
# Validation score: 0.869048
# Iteration 6, loss = 0.31240650
# Validation score: 0.875149
# Iteration 7, loss = 0.30303028
# Validation score: 0.872768
# Iteration 8, loss = 0.29165058
# Validation score: 0.875000
# Iteration 9, loss = 0.26989964
# Validation score: 0.878125
# Iteration 10, loss = 0.26557451
# Validation score: 0.881101
# Iteration 11, loss = 0.25044462
# Validation score: 0.874405
# Iteration 12, loss = 0.24733303
# Validation score: 0.876935
# Iteration 13, loss = 0.23590727
# Validation score: 0.884821
# Iteration 14, loss = 0.22827511
# Validation score: 0.884226
# Iteration 15, loss = 0.21825665
# Validation score: 0.887649
# Iteration 16, loss = 0.20961273
# Validation score: 0.879613
# Iteration 17, loss = 0.20236952
# Validation score: 0.887202
# Iteration 18, loss = 0.19939380
# Validation score: 0.891071
# Iteration 19, loss = 0.19232228
# Validation score: 0.884077
# Iteration 20, loss = 0.18494624
# Validation score: 0.885119
# Iteration 21, loss = 0.18154556
# Validation score: 0.889732
# Iteration 22, loss = 0.17181644
# Validation score: 0.882738
# Iteration 23, loss = 0.16584491
# Validation score: 0.886012
# Iteration 24, loss = 0.16565382
# Validation score: 0.879018
# Iteration 25, loss = 0.15258718
# Validation score: 0.887500
# Iteration 26, loss = 0.15121182
# Validation score: 0.888393
# Iteration 27, loss = 0.14047203
# Validation score: 0.890625
# Iteration 28, loss = 0.14374880
# Validation score: 0.881994
# Iteration 29, loss = 0.13423364
# Validation score: 0.882143
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.82900086
# Validation score: 0.803125
# Iteration 2, loss = 0.49656650
# Validation score: 0.845052
# Iteration 3, loss = 0.44745922
# Validation score: 0.850521
# Iteration 4, loss = 0.40322316
# Validation score: 0.838021
# Iteration 5, loss = 0.38476086
# Validation score: 0.857031
# Iteration 6, loss = 0.36366763
# Validation score: 0.850521
# Iteration 7, loss = 0.34092741
# Validation score: 0.866146
# Iteration 8, loss = 0.31952820
# Validation score: 0.853125
# Iteration 9, loss = 0.30198444
# Validation score: 0.871354
# Iteration 10, loss = 0.29113634
# Validation score: 0.876302
# Iteration 11, loss = 0.27892874
# Validation score: 0.861198
# Iteration 12, loss = 0.27019088
# Validation score: 0.863021
# Iteration 13, loss = 0.26341494
# Validation score: 0.864844
# Iteration 14, loss = 0.24241255
# Validation score: 0.871615
# Iteration 15, loss = 0.24283943
# Validation score: 0.877083
# Iteration 16, loss = 0.23001134
# Validation score: 0.866146
# Iteration 17, loss = 0.22346565
# Validation score: 0.875781
# Iteration 18, loss = 0.22062319
# Validation score: 0.873698
# Iteration 19, loss = 0.20344259
# Validation score: 0.875781
# Iteration 20, loss = 0.19928908
# Validation score: 0.876302
# Iteration 21, loss = 0.18740837
# Validation score: 0.880208
# Iteration 22, loss = 0.18295393
# Validation score: 0.880208
# Iteration 23, loss = 0.17809387
# Validation score: 0.873698
# Iteration 24, loss = 0.16932165
# Validation score: 0.879687
# Iteration 25, loss = 0.16860909
# Validation score: 0.876823
# Iteration 26, loss = 0.16292889
# Validation score: 0.874219
# Iteration 27, loss = 0.14685129
# Validation score: 0.870833
# Iteration 28, loss = 0.15033577
# Validation score: 0.874479
# Iteration 29, loss = 0.15220869
# Validation score: 0.872917
# Iteration 30, loss = 0.14145012
# Validation score: 0.880990
# Iteration 31, loss = 0.13451650
# Validation score: 0.861458
# Iteration 32, loss = 0.13200361
# Validation score: 0.878385
# Iteration 33, loss = 0.11514315
# Validation score: 0.876823
# Iteration 34, loss = 0.11466534
# Validation score: 0.874219
# Iteration 35, loss = 0.10862667
# Validation score: 0.876042
# Iteration 36, loss = 0.10941397
# Validation score: 0.869531
# Iteration 37, loss = 0.10207435
# Validation score: 0.871875
# Iteration 38, loss = 0.09695108
# Validation score: 0.871875
# Iteration 39, loss = 0.10356769
# Validation score: 0.878906
# Iteration 40, loss = 0.09845999
# Validation score: 0.876823
# Iteration 41, loss = 0.08780361
# Validation score: 0.870833
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.71198338
# Validation score: 0.826215
# Iteration 2, loss = 0.45020831
# Validation score: 0.842361
# Iteration 3, loss = 0.40272413
# Validation score: 0.851562
# Iteration 4, loss = 0.36797689
# Validation score: 0.859028
# Iteration 5, loss = 0.34723363
# Validation score: 0.853299
# Iteration 6, loss = 0.32971681
# Validation score: 0.864757
# Iteration 7, loss = 0.31148845
# Validation score: 0.873264
# Iteration 8, loss = 0.29978595
# Validation score: 0.876389
# Iteration 9, loss = 0.27827623
# Validation score: 0.872743
# Iteration 10, loss = 0.27033585
# Validation score: 0.871528
# Iteration 11, loss = 0.25514298
# Validation score: 0.879167
# Iteration 12, loss = 0.24990104
# Validation score: 0.864583
# Iteration 13, loss = 0.24634529
# Validation score: 0.883160
# Iteration 14, loss = 0.22650912
# Validation score: 0.874653
# Iteration 15, loss = 0.22473596
# Validation score: 0.885243
# Iteration 16, loss = 0.22261672
# Validation score: 0.885764
# Iteration 17, loss = 0.20542837
# Validation score: 0.879340
# Iteration 18, loss = 0.20140195
# Validation score: 0.884896
# Iteration 19, loss = 0.19356182
# Validation score: 0.878472
# Iteration 20, loss = 0.18741769
# Validation score: 0.886806
# Iteration 21, loss = 0.18374046
# Validation score: 0.878819
# Iteration 22, loss = 0.17640979
# Validation score: 0.886285
# Iteration 23, loss = 0.16748834
# Validation score: 0.872743
# Iteration 24, loss = 0.16708962
# Validation score: 0.879687
# Iteration 25, loss = 0.15936938
# Validation score: 0.883507
# Iteration 26, loss = 0.15187616
# Validation score: 0.880729
# Iteration 27, loss = 0.14936724
# Validation score: 0.880035
# Iteration 28, loss = 0.13544010
# Validation score: 0.879687
# Iteration 29, loss = 0.13885221
# Validation score: 0.882639
# Iteration 30, loss = 0.12486996
# Validation score: 0.889062
# Iteration 31, loss = 0.12955583
# Validation score: 0.884722
# Iteration 32, loss = 0.11313015
# Validation score: 0.893576
# Iteration 33, loss = 0.11845063
# Validation score: 0.889410
# Iteration 34, loss = 0.11250567
# Validation score: 0.883507
# Iteration 35, loss = 0.11131910
# Validation score: 0.870486
# Iteration 36, loss = 0.10331336
# Validation score: 0.889583
# Iteration 37, loss = 0.09953382
# Validation score: 0.888194
# Iteration 38, loss = 0.09505060
# Validation score: 0.883681
# Iteration 39, loss = 0.09185447
# Validation score: 0.887153
# Iteration 40, loss = 0.09709363
# Validation score: 0.861285
# Iteration 41, loss = 0.09849915
# Validation score: 0.886111
# Iteration 42, loss = 0.09239440
# Validation score: 0.883854
# Iteration 43, loss = 0.08192553
# Validation score: 0.878646
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.68772542
# Validation score: 0.830208
# Iteration 2, loss = 0.43773971
# Validation score: 0.857887
# Iteration 3, loss = 0.38996258
# Validation score: 0.848214
# Iteration 4, loss = 0.36421331
# Validation score: 0.861310
# Iteration 5, loss = 0.33779592
# Validation score: 0.869048
# Iteration 6, loss = 0.31240650
# Validation score: 0.875149
# Iteration 7, loss = 0.30303028
# ...
# Iteration 17, loss = 0.20081103
# Validation score: 0.882422
# Iteration 18, loss = 0.18967283
# Validation score: 0.886328
# Iteration 19, loss = 0.18729371
# Validation score: 0.890495
# Iteration 20, loss = 0.17605891
# Validation score: 0.882031
# Iteration 21, loss = 0.17017615
# Validation score: 0.894922
# Iteration 22, loss = 0.16652435
# Validation score: 0.890234
# Iteration 23, loss = 0.16091781
# Validation score: 0.877865
# Iteration 24, loss = 0.15886731
# Validation score: 0.889453
# Iteration 25, loss = 0.14787556
# Validation score: 0.890234
# Iteration 26, loss = 0.14185509
# Validation score: 0.894401
# Iteration 27, loss = 0.13601413
# Validation score: 0.897266
# Iteration 28, loss = 0.13462630
# Validation score: 0.882943
# Iteration 29, loss = 0.13226755
# Validation score: 0.893099
# Iteration 30, loss = 0.12544376
# Validation score: 0.888411
# Iteration 31, loss = 0.13037010
# Validation score: 0.893229
# Iteration 32, loss = 0.11232799
# Validation score: 0.886979
# Iteration 33, loss = 0.11318879
# Validation score: 0.890885
# Iteration 34, loss = 0.10316317
# Validation score: 0.887891
# Iteration 35, loss = 0.10468108
# Validation score: 0.887891
# Iteration 36, loss = 0.10901593
# Validation score: 0.886719
# Iteration 37, loss = 0.09686551
# Validation score: 0.886979
# Iteration 38, loss = 0.09495716
# Validation score: 0.887370
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.62144375
# Validation score: 0.828333
# Iteration 2, loss = 0.40967526
# Validation score: 0.850625
# Iteration 3, loss = 0.36417399
# Validation score: 0.863229
# Iteration 4, loss = 0.34051112
# Validation score: 0.861146
# Iteration 5, loss = 0.31445064
# Validation score: 0.872292
# Iteration 6, loss = 0.30177350
# Validation score: 0.865625
# Iteration 7, loss = 0.28244347
# Validation score: 0.871563
# Iteration 8, loss = 0.27193607
# Validation score: 0.877500
# Iteration 9, loss = 0.25810661
# Validation score: 0.876354
# Iteration 10, loss = 0.25194725
# Validation score: 0.877917
# Iteration 11, loss = 0.23931758
# Validation score: 0.881146
# Iteration 12, loss = 0.23090389
# Validation score: 0.881042
# Iteration 13, loss = 0.22872831
# Validation score: 0.881563
# Iteration 14, loss = 0.21712190
# Validation score: 0.876875
# Iteration 15, loss = 0.21329911
# Validation score: 0.873958
# Iteration 16, loss = 0.20153580
# Validation score: 0.883125
# Iteration 17, loss = 0.19328872
# Validation score: 0.877292
# Iteration 18, loss = 0.18867723
# Validation score: 0.878021
# Iteration 19, loss = 0.18664112
# Validation score: 0.890104
# Iteration 20, loss = 0.18008693
# Validation score: 0.890833
# Iteration 21, loss = 0.17412244
# Validation score: 0.885000
# Iteration 22, loss = 0.16484256
# Validation score: 0.888542
# Iteration 23, loss = 0.16494219
# Validation score: 0.882917
# Iteration 24, loss = 0.15668970
# Validation score: 0.888646
# Iteration 25, loss = 0.14656827
# Validation score: 0.888854
# Iteration 26, loss = 0.14262846
# Validation score: 0.888958
# Iteration 27, loss = 0.14197197
# Validation score: 0.886771
# Iteration 28, loss = 0.13436024
# Validation score: 0.886875
# Iteration 29, loss = 0.13014735
# Validation score: 0.887813
# Iteration 30, loss = 0.12127910
# Validation score: 0.891250
# Iteration 31, loss = 0.12348493
# Validation score: 0.885312
# Iteration 32, loss = 0.11763320
# Validation score: 0.886458
# Iteration 33, loss = 0.11438917
# Validation score: 0.882292
# Iteration 34, loss = 0.11248749
# Validation score: 0.881354
# Iteration 35, loss = 0.10175296
# Validation score: 0.888437
# Iteration 36, loss = 0.09810870
# Validation score: 0.886354
# Iteration 37, loss = 0.10108106
# Validation score: 0.888437
# Iteration 38, loss = 0.09806187
# Validation score: 0.889062
# Iteration 39, loss = 0.08809165
# Validation score: 0.886563
# Iteration 40, loss = 0.08735569
# Validation score: 0.887292
# Iteration 41, loss = 0.08391378
# Validation score: 0.888646
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.68549439
# Validation score: 0.819345
# Iteration 2, loss = 0.44202323
# Validation score: 0.849554
# Iteration 3, loss = 0.39169469
# Validation score: 0.855060
# Iteration 4, loss = 0.35795663
# Validation score: 0.867113
# Iteration 5, loss = 0.33446805
# Validation score: 0.873512
# Iteration 6, loss = 0.31763319
# Validation score: 0.875744
# Iteration 7, loss = 0.29418743
# Validation score: 0.873958
# Iteration 8, loss = 0.29458652
# Validation score: 0.875595
# Iteration 9, loss = 0.27565294
# Validation score: 0.883333
# Iteration 10, loss = 0.26725716
# Validation score: 0.879613
# Iteration 11, loss = 0.24962996
# Validation score: 0.878274
# Iteration 12, loss = 0.24163185
# Validation score: 0.881994
# Iteration 13, loss = 0.23534622
# Validation score: 0.874107
# Iteration 14, loss = 0.22998465
# Validation score: 0.885565
# Iteration 15, loss = 0.21907587
# Validation score: 0.884821
# Iteration 16, loss = 0.20782036
# Validation score: 0.876786
# Iteration 17, loss = 0.20322713
# Validation score: 0.885565
# Iteration 18, loss = 0.19722001
# Validation score: 0.888542
# Iteration 19, loss = 0.19233395
# Validation score: 0.881845
# Iteration 20, loss = 0.18042355
# Validation score: 0.886458
# Iteration 21, loss = 0.18143596
# Validation score: 0.881994
# Iteration 22, loss = 0.17529139
# Validation score: 0.884375
# Iteration 23, loss = 0.16594839
# Validation score: 0.880208
# Iteration 24, loss = 0.15498053
# Validation score: 0.884970
# Iteration 25, loss = 0.15198364
# Validation score: 0.886310
# Iteration 26, loss = 0.14809669
# Validation score: 0.887500
# Iteration 27, loss = 0.14229767
# Validation score: 0.885268
# Iteration 28, loss = 0.14414806
# Validation score: 0.888542
# Iteration 29, loss = 0.13346158
# Validation score: 0.888690
# Iteration 30, loss = 0.12741055
# Validation score: 0.888095
# Iteration 31, loss = 0.12225790
# Validation score: 0.886458
# Iteration 32, loss = 0.12200356
# Validation score: 0.887798
# Iteration 33, loss = 0.11486779
# Validation score: 0.881101
# Iteration 34, loss = 0.11084193
# Validation score: 0.880804
# Iteration 35, loss = 0.10871646
# Validation score: 0.889435
# Iteration 36, loss = 0.10002601
# Validation score: 0.890179
# Iteration 37, loss = 0.09576568
# Validation score: 0.884821
# Iteration 38, loss = 0.09535449
# Validation score: 0.888393
# Iteration 39, loss = 0.09275112
# Validation score: 0.886458
# Iteration 40, loss = 0.09492123
# Validation score: 0.884970
# Iteration 41, loss = 0.08687018
# Validation score: 0.882292
# Iteration 42, loss = 0.08741621
# Validation score: 0.889435
# Iteration 43, loss = 0.08753184
# Validation score: 0.887946
# Iteration 44, loss = 0.07981180
# Validation score: 0.885268
# Iteration 45, loss = 0.06784388
# Validation score: 0.886012
# Iteration 46, loss = 0.07109365
# Validation score: 0.882887
# Iteration 47, loss = 0.07745570
# Validation score: 0.885863
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.62848455
# Validation score: 0.836667
# Iteration 2, loss = 0.41783578
# Validation score: 0.861458
# Iteration 3, loss = 0.36285722
# Validation score: 0.862604
# Iteration 4, loss = 0.34047639
# Validation score: 0.869062
# Iteration 5, loss = 0.31588785
# Validation score: 0.878854
# Iteration 6, loss = 0.29683068
# Validation score: 0.882604
# Iteration 7, loss = 0.28041285
# Validation score: 0.883542
# Iteration 8, loss = 0.27183507
# Validation score: 0.869271
# Iteration 9, loss = 0.25898532
# Validation score: 0.885417
# Iteration 10, loss = 0.25071967
# Validation score: 0.884479
# Iteration 11, loss = 0.24175830
# Validation score: 0.874792
# Iteration 12, loss = 0.22953633
# Validation score: 0.883750
# Iteration 13, loss = 0.22318717
# Validation score: 0.875521
# Iteration 14, loss = 0.21807779
# Validation score: 0.877500
# Iteration 15, loss = 0.20788201
# Validation score: 0.879375
# Iteration 16, loss = 0.20187398
# Validation score: 0.890208
# Iteration 17, loss = 0.19684017
# Validation score: 0.883542
# Iteration 18, loss = 0.18845806
# Validation score: 0.886250
# Iteration 19, loss = 0.18197759
# Validation score: 0.886146
# Iteration 20, loss = 0.17793693
# Validation score: 0.891042
# Iteration 21, loss = 0.17432422
# Validation score: 0.890729
# Iteration 22, loss = 0.16896036
# Validation score: 0.886667
# Iteration 23, loss = 0.16012996
# Validation score: 0.890625
# Iteration 24, loss = 0.15259348
# Validation score: 0.888542
# Iteration 25, loss = 0.14717473
# Validation score: 0.892396
# Iteration 26, loss = 0.13953477
# Validation score: 0.889896
# Iteration 27, loss = 0.14404771
# Validation score: 0.885417
# Iteration 28, loss = 0.13144765
# Validation score: 0.886979
# Iteration 29, loss = 0.13582377
# Validation score: 0.887604
# Iteration 30, loss = 0.12438420
# Validation score: 0.887292
# Iteration 31, loss = 0.11626031
# Validation score: 0.886667
# Iteration 32, loss = 0.11652822
# Validation score: 0.891146
# Iteration 33, loss = 0.11342030
# Validation score: 0.887813
# Iteration 34, loss = 0.10952230
# Validation score: 0.884479
# Iteration 35, loss = 0.10975082
# Validation score: 0.885208
# Iteration 36, loss = 0.09929062
# Validation score: 0.888958
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.39904111
# Validation score: 0.719792
# Iteration 2, loss = 0.71522222
# Validation score: 0.764583
# Iteration 3, loss = 0.58724832
# Validation score: 0.802083
# Iteration 4, loss = 0.50886743
# Validation score: 0.822917
# Iteration 5, loss = 0.47241965
# Validation score: 0.825000
# Iteration 6, loss = 0.44331690
# Validation score: 0.822917
# Iteration 7, loss = 0.44400966
# Validation score: 0.830208
# Iteration 8, loss = 0.41865355
# Validation score: 0.829167
# Iteration 9, loss = 0.38562016
# Validation score: 0.840625
# Iteration 10, loss = 0.36524007
# Validation score: 0.815625
# Iteration 11, loss = 0.37025939
# Validation score: 0.821875
# Iteration 12, loss = 0.35192249
# Validation score: 0.838542
# Iteration 13, loss = 0.31772238
# Validation score: 0.846875
# Iteration 14, loss = 0.30754998
# Validation score: 0.842708
# Iteration 15, loss = 0.31280208
# Validation score: 0.841667
# Iteration 16, loss = 0.28369517
# Validation score: 0.831250
# Iteration 17, loss = 0.28966575
# Validation score: 0.856250
# Iteration 18, loss = 0.26313548
# Validation score: 0.858333
# Iteration 19, loss = 0.25749303
# Validation score: 0.833333
# Iteration 20, loss = 0.24803815
# Validation score: 0.843750
# Iteration 21, loss = 0.22934733
# Validation score: 0.839583
# Iteration 22, loss = 0.23941647
# Validation score: 0.826042
# Iteration 23, loss = 0.22437409
# Validation score: 0.854167
# Iteration 24, loss = 0.21907480
# Validation score: 0.852083
# Iteration 25, loss = 0.20790922
# Validation score: 0.819792
# Iteration 26, loss = 0.23569483
# Validation score: 0.837500
# Iteration 27, loss = 0.20001030
# Validation score: 0.846875
# Iteration 28, loss = 0.21017483
# Validation score: 0.854167
# Iteration 29, loss = 0.19598988
# Validation score: 0.848958
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.62597669
# Validation score: 0.830417
# Iteration 2, loss = 0.40952184
# Validation score: 0.844583
# Iteration 3, loss = 0.36606752
# Validation score: 0.866979
# Iteration 4, loss = 0.33340897
# Validation score: 0.874375
# Iteration 5, loss = 0.31427657
# Validation score: 0.872708
# Iteration 6, loss = 0.29796496
# Validation score: 0.870208
# Iteration 7, loss = 0.28045750
# Validation score: 0.878542
# Iteration 8, loss = 0.26568288
# Validation score: 0.881875
# Iteration 9, loss = 0.26121020
# Validation score: 0.875938
# Iteration 10, loss = 0.24769845
# Validation score: 0.886354
# Iteration 11, loss = 0.23649669
# Validation score: 0.885312
# Iteration 12, loss = 0.22801111
# Validation score: 0.878125
# Iteration 13, loss = 0.22255443
# Validation score: 0.885000
# Iteration 14, loss = 0.21376488
# Validation score: 0.885521
# Iteration 15, loss = 0.21028894
# Validation score: 0.883021
# Iteration 16, loss = 0.20075157
# Validation score: 0.887083
# Iteration 17, loss = 0.18863903
# Validation score: 0.886563
# Iteration 18, loss = 0.18321265
# Validation score: 0.886354
# Iteration 19, loss = 0.18158439
# Validation score: 0.885938
# Iteration 20, loss = 0.17233163
# Validation score: 0.889271
# Iteration 21, loss = 0.17032417
# Validation score: 0.892292
# Iteration 22, loss = 0.16321527
# Validation score: 0.881875
# Iteration 23, loss = 0.16157449
# Validation score: 0.885521
# Iteration 24, loss = 0.15032768
# Validation score: 0.884479
# Iteration 25, loss = 0.15059255
# Validation score: 0.887708
# Iteration 26, loss = 0.13985564
# Validation score: 0.887500
# Iteration 27, loss = 0.14117633
# Validation score: 0.888854
# Iteration 28, loss = 0.13061437
# Validation score: 0.886042
# Iteration 29, loss = 0.12989987
# Validation score: 0.883229
# Iteration 30, loss = 0.12472814
# Validation score: 0.894792
# Iteration 31, loss = 0.11945671
# Validation score: 0.890938
# Iteration 32, loss = 0.11596563
# Validation score: 0.883125
# Iteration 33, loss = 0.11175713
# Validation score: 0.892292
# Iteration 34, loss = 0.10938011
# Validation score: 0.893958
# Iteration 35, loss = 0.10460556
# Validation score: 0.889687
# Iteration 36, loss = 0.09784404
# Validation score: 0.886146
# Iteration 37, loss = 0.09691389
# Validation score: 0.887500
# Iteration 38, loss = 0.09268158
# Validation score: 0.891250
# Iteration 39, loss = 0.09728565
# Validation score: 0.887292
# Iteration 40, loss = 0.08744967
# Validation score: 0.891354
# Iteration 41, loss = 0.08787212
# Validation score: 0.892396
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.62980189
# Validation score: 0.832187
# Iteration 2, loss = 0.42151964
# Validation score: 0.852396
# Iteration 3, loss = 0.36776550
# Validation score: 0.855208
# Iteration 4, loss = 0.34456439
# Validation score: 0.864167
# Iteration 5, loss = 0.31642268
# Validation score: 0.874792
# Iteration 6, loss = 0.30658910
# Validation score: 0.877083
# Iteration 7, loss = 0.28482311
# Validation score: 0.873542
# Iteration 8, loss = 0.27387633
# Validation score: 0.867396
# Iteration 9, loss = 0.26454616
# Validation score: 0.881146
# Iteration 10, loss = 0.25486958
# Validation score: 0.873437
# Iteration 11, loss = 0.24529300
# Validation score: 0.875417
# Iteration 12, loss = 0.23652600
# Validation score: 0.871458
# Iteration 13, loss = 0.22607586
# Validation score: 0.881667
# Iteration 14, loss = 0.21649196
# Validation score: 0.877396
# Iteration 15, loss = 0.20934980
# Validation score: 0.880313
# Iteration 16, loss = 0.20562431
# Validation score: 0.885312
# Iteration 17, loss = 0.19886212
# Validation score: 0.885521
# Iteration 18, loss = 0.19367213
# Validation score: 0.877188
# Iteration 19, loss = 0.18627035
# Validation score: 0.883437
# Iteration 20, loss = 0.17903944
# Validation score: 0.887604
# Iteration 21, loss = 0.17385069
# Validation score: 0.888229
# Iteration 22, loss = 0.16636332
# Validation score: 0.885521
# Iteration 23, loss = 0.16127757
# Validation score: 0.885625
# Iteration 24, loss = 0.15614693
# Validation score: 0.888542
# Iteration 25, loss = 0.15065142
# Validation score: 0.887917
# Iteration 26, loss = 0.14332812
# Validation score: 0.886979
# Iteration 27, loss = 0.14043621
# Validation score: 0.885833
# Iteration 28, loss = 0.13590117
# Validation score: 0.885000
# Iteration 29, loss = 0.13310723
# Validation score: 0.883021
# Iteration 30, loss = 0.12602570
# Validation score: 0.887188
# Iteration 31, loss = 0.12710708
# Validation score: 0.886875
# Iteration 32, loss = 0.11423003
# Validation score: 0.887500
# Iteration 33, loss = 0.11380247
# Validation score: 0.887917
# Iteration 34, loss = 0.11066297
# Validation score: 0.892813
# Iteration 35, loss = 0.10673799
# Validation score: 0.885104
# Iteration 36, loss = 0.10328950
# Validation score: 0.889583
# Iteration 37, loss = 0.09675894
# Validation score: 0.884375
# Iteration 38, loss = 0.09745420
# Validation score: 0.884792
# Iteration 39, loss = 0.09326129
# Validation score: 0.887292
# Iteration 40, loss = 0.09833239
# Validation score: 0.888229
# Iteration 41, loss = 0.08823817
# Validation score: 0.888125
# Iteration 42, loss = 0.08490107
# Validation score: 0.886042
# Iteration 43, loss = 0.08881790
# Validation score: 0.887917
# Iteration 44, loss = 0.07814515
# Validation score: 0.882083
# Iteration 45, loss = 0.07510597
# Validation score: 0.888229
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_image(i, predictions_array, true_label, img):
    true_label, img = true_label.iloc[i], img.iloc[i].values.reshape(28,28)
    
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap='gray') 
    
    predicted_label = np.argmax(predictions_array)
    color = 'blue' if predicted_label == true_label else 'red'

    plt.xlabel(f"{class_names[predicted_label]} {100*np.max(predictions_array):.2f}% ({class_names[true_label]})", color=color)
    
def plot_value_array(i, predictions_array, true_label):
    true_label = true_label.iloc[i]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

i = 19
plt.figure(figsize=(6, 3))

plt.subplot(1, 2, 1)
plot_image(i, predictions_sklearn[i], test_labels, test_images)
plt.subplot(1, 2, 2)
plot_value_array(i, predictions_sklearn[i], test_labels)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def save_image_only(i, true_label, img):
    img = img.iloc[i].values.reshape(28, 28)

    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.savefig(f"image_only_{i}.jpeg", bbox_inches='tight', pad_inches=0)
    plt.close()

i = 19
save_image_only(i, test_labels, test_images)

# %%
import pandas as pd

data = {
    'Model' : ['TensorFlow', 'Scikit-Learn'],
    'Accuracy' : [test_acc_tf, test_acc_sklearn],
    'Architecture': ['Neural Network (2 hidden layers)', 'MLP (2 hidden layers)'],
    'Early Stopping' : ['Yes', 'Yes']
}

comparison_df = pd.DataFrame(data)

best_model = comparison_df.loc[comparison_df['Accuracy'].idxmax()]
print("Comparison of Model Performance:")
print(comparison_df)
print("Comparison Model Based on Accuracy:")
print(best_model)
# Out:
# Comparison of Model Performance:
#           Model  Accuracy                      Architecture Early Stopping
# 0    TensorFlow    0.8848  Neural Network (2 hidden layers)            Yes
# 1  Scikit-Learn    0.8853             MLP (2 hidden layers)            Yes
# Comparison Model Based on Accuracy:
# Model                      Scikit-Learn
# Accuracy                         0.8853
# Architecture      MLP (2 hidden layers)
# Early Stopping                      Yes
# Name: 1, dtype: object

# %%
import pickle
#Cara dump pickle jika model sklearn yang terbaik
# Misalnya `model_sklearn` adalah model terbaik Anda dari Scikit-Learn
with open('best_model.pdf', 'wb') as file:
    pickle.dump(model_sklearn, file)

# %%
import pickle
import tensorflow as tf
#Cara dump h5 jika model tensorflow yang terbaik
# Menyimpan model TensorFlow
model_tf.save('best_model_tf.h5')
